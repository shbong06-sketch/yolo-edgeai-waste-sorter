# %%
# 1. Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. 프로젝트 폴더로 이동
# %cd /content/drive/MyDrive/project_01_yolo

# %%
# 3. 모델 비교 실행
# %run AI/src/training/compare_models.py
